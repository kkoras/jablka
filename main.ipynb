# %%
import pandas as pd
import numpy as np

def pair_wise_spread(df1, df2):
    """ Calculates spread between prices on two different markets"""
    return max(df1.bid-df2.ask, df2.bid-df1.ask)  #Checked

def markets_with_highest_spread(list_of_markets):
    """Returns two markets having maximum pair-spread at given moment and correspodning spread"""
    current_max=-200.
    max_market1_idx=0
    max_market2_idx=0
    for i in range(len(list_of_markets)):
        for j in range(len(list_of_markets)):
            current_spread=pair_wise_spread(list_of_markets[i], list_of_markets[j])
            if current_spread>current_max:
                current_max=current_spread
                max_market1_idx=i
                max_market2_idx=j
                
    return max_market1_idx, max_market2_idx, current_max   #Checked

def markets_with_best_spread(list_of_markets, X):
    """Searches for two markets that meet the spread treshold"""
    market1_idx = 0
    market2_idx = 0
    for i in range(len(list_of_markets)):
        for j in range(len(list_of_markets)):
            spread=pair_wise_spread(list_of_markets[i], list_of_markets[j])
            if spread>X:
                return i, j, spread
                
    return None

    

def apples_bought_open_long(market, capital):
    """Returns amount of (virtual) apples bought at an opening transaction price (Ask), given invested capital""" 
    return capital/market.ask #Checked

def dollars_earned_opening_short(market, apples):
    """ Returns dollars earned by opening short (selling virtual apples)"""
    return apples*market.bid

def dollars_spent_closing_short(market, apples):
    """Returns money spent on closing (buying) previously opened short position"""
    return apples*market.ask #Checked

def dollars_earned_closing_long(market, apples):
    """Returns money earned by closing (selling) previously opened long position"""
    return apples*market.bid

def search_for_opportunity_open(list_of_markets, X):
    """Searches for arbitrage opportunity to open transactions"""
    max_market1_idx, max_market2_idx, max_spread=markets_with_highest_spread(list_of_markets)
    if max_spread >= X:
        return max_market1_idx, max_market2_idx, max_spread
    else:
        return None  #Checked
    
    
def identify_short_and_long_markets(market1_idx, market2_idx, market_list):
    """Given markets with highest spread, returns which market dedicated for long position, and market dedicated
    for short position"""
    if market_list[market1_idx].ask < market_list[market2_idx].bid:
        long_market_idx, short_market_idx = market1_idx, market2_idx
    else:
        long_market_idx, short_market_idx = market2_idx, market1_idx
    return long_market_idx, short_market_idx   #Checked

def close_opportunity(long_market_idx, short_market_idx, Y, market_list):
    """Returns True if there is a opportunity to close, False otherwise"""
    close_spread=market_list[long_market_idx].bid - market_list[short_market_idx].ask
    if close_spread >= Y:
        return True
    return False   #Checked

    
    
def arbitrage_strategy(market_list, X, Y, time_to_close, long_ratio, start_capital=1000., display_logs=False):
    """Implements arbitrage algorithm"""
    #Initialazing variables
    current_capital=start_capital
    moment=0
    look_for_short=True   #Checking if we are during arbitrage
    time_in_arbitrage=0   #Time in which we are in arbitrage, measured in ticks
    while moment < (market_list[0].shape[0] -1):
        #Price data from all markets at given time
        markets_at_moment=[market.iloc[moment, :] for market in market_list]
        
        if look_for_short:
            #Checking if there is an opportunity for opening transactions
            if markets_with_best_spread(markets_at_moment, X):
                if display_logs:
                    print "Opening positions at moment {}".format(moment)
                #If there is, identify the best pair
                max_market1, max_market2, max_spread = markets_with_best_spread(markets_at_moment, X)
                
                #Identyfing long and short markets
                long_market, short_market=identify_short_and_long_markets(max_market1, max_market2, markets_at_moment)
                
                #Capital calculations related to opening positions. Keeping things simple: every transaction (opening and closing, long and
                #short) will be conducted in separate calculation
                money_invested_in_long=current_capital*long_ratio
                
                #Buying (opening long position)
                apples=apples_bought_open_long(markets_at_moment[long_market], money_invested_in_long)
                current_capital = current_capital - money_invested_in_long
                
                #Selling (opening short position)
                dollars_earned_on_short = dollars_earned_opening_short(markets_at_moment[short_market], apples)
                current_capital = current_capital + dollars_earned_on_short
                
                #Now we are done with opening calculations
                look_for_short = False
                time_in_arbitrage=1
                moment+=1   #Advancing time, we assume that we cannot close position in the same moment in which we opened them
                continue    #Skipping rest of the iteration
            else:
                #If we are looking for opening opportunity, but there isn't one good enough
                moment+=1
                continue   #Skipping rest of the iteration
        
        if not look_for_short:    #That means we are during arbitrage
            #Checking is there a good opportunity to close or did we exceed time limit Y
            
            if (close_opportunity(long_market, short_market, Y, markets_at_moment)) or (time_in_arbitrage > time_to_close):
                #Calculations related to closing positions
                if display_logs:
                    print "Closing positions at moment {}".format(moment)
                    print ""
                
                #Closing (buying back) short
                dollars_spent_on_closing_short = dollars_spent_closing_short(markets_at_moment[short_market], apples)
                current_capital = current_capital - dollars_spent_on_closing_short
                
                #Closing (selling) long
                dollars_earned_on_closing_long = dollars_earned_closing_long(markets_at_moment[long_market], apples)
                current_capital = current_capital + dollars_earned_on_closing_long
                
                #If we closed recently opened positions we can look for next opening positions
                time_in_arbitrage = 0
                look_for_short = True
                moment+=1
            
            else:
                #If we did not exceed time limit, but there is no good opportunity at the moment
                time_in_arbitrage+=1
                moment+=1
    
    #Outside the loop; when we reach the final record
    if look_for_short:
        #If we are in open-opportunities mode we do nothing since we will not be able to close any transaction
        pass
    else:
        #If we have currently open positions we close them
        if display_logs:
            print "Closing positions at moment {}".format(moment)
        
        dollars_spent_on_closing_short = dollars_spent_closing_short(markets_at_moment[short_market], apples)
        current_capital = current_capital - dollars_spent_on_closing_short
                
        dollars_earned_on_closing_long = dollars_earned_closing_long(markets_at_moment[long_market], apples)
        current_capital = current_capital + dollars_earned_on_closing_long
    
    #Finally, we return our capital after performing the strategy
    return current_capital

def two_step_strategy(market_list, X, Y, time_to_close, long_ratio, start_capital=1000., display_logs=False):
    """Allows to perform strategy on all given data (using targ6 in the first period as well)"""
    
    #Step one
    market_list_first=[df.iloc[:659, :] for df in market_list]
    capital_after_step1=arbitrage_strategy(market_list_first, X, Y, time_to_close, long_ratio, 
                                           start_capital, display_logs)
    
    #Step two
    market_list_second = [df.iloc[659:, :] for df in market_list if df.shape[0] != 659]
    capital_after_step_two = arbitrage_strategy(market_list_second, X, Y, time_to_close, long_ratio,
                                               capital_after_step1, display_logs)
    
    return capital_after_step_two

def grid_search(param_grid, market_list, start_capital, data_piece=100000, display_progress=False):
    """ Brute force search for best parameters, param_grid is a dictionary in form (parameter: values_to_consider).
    Since we use nested loops, we assume parameters are independent"""
    counter=1
    market_list=[df.iloc[:data_piece, :] for df in market_list]
    current_max_capital=0
    for X in param_grid["X"]:
        for Y in param_grid["Y"]:
            for time_to_close in param_grid["time_to_close"]:
                for long_ratio in param_grid["long_ratio"]:
                    current_end_capital = arbitrage_strategy(market_list, X, Y, time_to_close, long_ratio, 
                                                            start_capital ,display_logs=False)
                    if current_end_capital > current_max_capital:
                        current_max_capital = current_end_capital
                        best_params = (X, Y, time_to_close, long_ratio)
                    if display_progress:
                        print "{} combinations checked".format(counter)
                        print "Best capital so far: {}".format(current_max_capital)
                        print ""
                        counter+=1
                            
                            
    print "Best params: X: {}, Y: {}, time_to_close: {}, long_ratio: {}".format(best_params[0],
                                                                               best_params[1],
                                                                               best_params[2],
                                                                               best_params[3])
    print "Best end capital: {}".format(current_max_capital)
    return best_params, current_max_capital

# %%
#Loading all seven files
targ1=pd.read_csv("targowisko-1.csv", sep=";", parse_dates=["Datetime"])
targ2=pd.read_csv("targowisko-2.csv", sep=";", parse_dates=["Datetime"])
targ3=pd.read_csv("targowisko-3.csv", sep=";", parse_dates=["Datetime"])
targ4=pd.read_csv("targowisko-4.csv", sep=";", parse_dates=["Datetime"])
targ5=pd.read_csv("targowisko-5.csv", sep=";", parse_dates=["Datetime"])
targ6=pd.read_csv("targowisko-6.csv", sep=";", parse_dates=["Datetime"])
targ7=pd.read_csv("targowisko-7.csv", sep=";", parse_dates=["Datetime"])


search_for_params=False

if search_for_params:
    market_list=[targ1, targ2, targ3, targ4, targ5, targ7]
    param_grid={"X": [1+20*i for i in range(10)],
               "Y": [-199 +i*20 for i in range(10)],
               "time_to_close": [10000],
               "long_ratio": [0.5]}

    best_params, best_capital=grid_search(param_grid, market_list, 1000., data_piece=10000, display_progress=True)
    print best_params
    print best_capital
    
    
market_list=[targ1, targ2, targ3, targ4, targ5, targ6, targ7]
end_capital=two_step_strategy(market_list, 81, -75., 10000, 0.5, display_logs=True)
print "Capital after performing the algorithm: {}".format(end_capital)
# Out:
# Opening positions at moment 0
# Closing positions at moment 658
# Opening positions at moment 0
# Closing positions at moment 1796
#
# Opening positions at moment 1799
# Closing positions at moment 2149
#
# Opening positions at moment 2151
# Closing positions at moment 2504
#
# Opening positions at moment 2611
# Closing positions at moment 2827
#
# Opening positions at moment 2969
# Closing positions at moment 3327
#
# Opening positions at moment 3380
# Closing positions at moment 4002
#
# Opening positions at moment 4444
# Closing positions at moment 4579
#
# Opening positions at moment 4759
# Closing positions at moment 4823
#
# Opening positions at moment 5026
# Closing positions at moment 5058
#
# Opening positions at moment 5565
# Closing positions at moment 5803
#
# Opening positions at moment 5899
# Closing positions at moment 6084
#
# Opening positions at moment 7252
# Closing positions at moment 9047
#
# Opening positions at moment 9057
# Closing positions at moment 9134
#
# Opening positions at moment 9202
# Closing positions at moment 9819
#
# Opening positions at moment 13773
# Closing positions at moment 13816
#
# Opening positions at moment 13824
# Closing positions at moment 13828
#
# Opening positions at moment 13834
# Closing positions at moment 13840
#
# Opening positions at moment 14767
# Closing positions at moment 14973
#
# Opening positions at moment 15311
# Closing positions at moment 15346
#
# Opening positions at moment 15538
# Closing positions at moment 16301
#
# Opening positions at moment 16305
# Closing positions at moment 20816
#
# Opening positions at moment 20817
# Closing positions at moment 21200
#
# Opening positions at moment 21584
# Closing positions at moment 31585
#
# Opening positions at moment 31586
# Closing positions at moment 41587
#
# Opening positions at moment 41588
# Closing positions at moment 51589
#
# Opening positions at moment 51590
# Closing positions at moment 61591
#
# Opening positions at moment 61592
# Closing positions at moment 71593
#
# Opening positions at moment 71594
# Closing positions at moment 79074
#
# Opening positions at moment 79118
# Closing positions at moment 79552
#
# Opening positions at moment 84354
# Closing positions at moment 85318
#
# Opening positions at moment 85393
# Closing positions at moment 87795
#
# Opening positions at moment 105116
# Closing positions at moment 105399
#
# Opening positions at moment 105968
# Closing positions at moment 106133
#
# Opening positions at moment 109583
# Closing positions at moment 109966
#
# Opening positions at moment 109983
# Closing positions at moment 110089
#
# Opening positions at moment 110090
# Closing positions at moment 110375
#
# Opening positions at moment 110376
# Closing positions at moment 112394
#
# Opening positions at moment 112414
# Closing positions at moment 112772
#
# Opening positions at moment 113433
# Closing positions at moment 113549
#
# Opening positions at moment 117506
# Closing positions at moment 117661
#
# Opening positions at moment 117908
# Closing positions at moment 118292
#
# Opening positions at moment 119036
# Closing positions at moment 119037
#
# Opening positions at moment 119245
# Closing positions at moment 119545
#
# Opening positions at moment 120278
# Closing positions at moment 122671
#
# Opening positions at moment 125461
# Closing positions at moment 125763
#
# Opening positions at moment 127938
# Closing positions at moment 128486
#
# Opening positions at moment 130276
# Closing positions at moment 130485
#
# Opening positions at moment 130656
# Closing positions at moment 131750
#
# Opening positions at moment 132411
# Closing positions at moment 134411
#
# Opening positions at moment 135613
# Closing positions at moment 138021
#
# Opening positions at moment 138023
# Closing positions at moment 148024
#
# Opening positions at moment 148025
# Closing positions at moment 156773
#
# Opening positions at moment 156820
# Closing positions at moment 158618
#
# Opening positions at moment 158906
# Closing positions at moment 162650
#
# Opening positions at moment 162821
# Closing positions at moment 163020
#
# Opening positions at moment 163420
# Closing positions at moment 164626
#
# Opening positions at moment 165011
# Closing positions at moment 175012
#
# Opening positions at moment 175013
# Closing positions at moment 178134
#
# Opening positions at moment 178140
# Closing positions at moment 178311
#
# Opening positions at moment 178338
# Closing positions at moment 178464
#
# Opening positions at moment 178537
# Closing positions at moment 178706
#
# Opening positions at moment 179288
# Closing positions at moment 180564
#
# Opening positions at moment 183192
# Closing positions at moment 183372
#
# Opening positions at moment 183798
# Closing positions at moment 187121
#
# Opening positions at moment 187854
# Closing positions at moment 189097
#
# Opening positions at moment 189184
# Closing positions at moment 189455
#
# Opening positions at moment 189568
# Closing positions at moment 189959
#
# Opening positions at moment 190050
# Closing positions at moment 191564
#
# Opening positions at moment 191900
# Closing positions at moment 201644
#
# Opening positions at moment 201879
# Closing positions at moment 203269
#
# Opening positions at moment 203529
# Closing positions at moment 204119
#
# Opening positions at moment 204135
# Closing positions at moment 204237
#
# Opening positions at moment 204367
# Closing positions at moment 214368
#
# Opening positions at moment 214369
# Closing positions at moment 218845
#
# Opening positions at moment 219862
# Closing positions at moment 220083
#
# Opening positions at moment 220614
# Closing positions at moment 227840
#
# Opening positions at moment 227841
# Closing positions at moment 227881
#
# Opening positions at moment 227882
# Closing positions at moment 229900
#
# Opening positions at moment 229901
# Closing positions at moment 233342
#
# Opening positions at moment 233343
# Closing positions at moment 243344
#
# Opening positions at moment 243345
# Closing positions at moment 253346
#
# Opening positions at moment 253347
# Closing positions at moment 255929
#
# Opening positions at moment 255930
# Closing positions at moment 265931
#
# Opening positions at moment 265932
# Closing positions at moment 275933
#
# Opening positions at moment 275934
# Closing positions at moment 285935
#
# Opening positions at moment 285936
# Closing positions at moment 295937
#
# Opening positions at moment 295938
# Closing positions at moment 299181
#
# Opening positions at moment 299236
# Closing positions at moment 299338
#
# Opening positions at moment 299345
# Closing positions at moment 300438
#
# Opening positions at moment 307141
# Closing positions at moment 307190
#
# Opening positions at moment 307507
# Closing positions at moment 307542
#
# Opening positions at moment 331948
# Closing positions at moment 332009
#
# Opening positions at moment 333694
# Closing positions at moment 333775
#
# Opening positions at moment 334580
# Closing positions at moment 334703
#
# Opening positions at moment 369456
# Closing positions at moment 369651
#
# Opening positions at moment 369745
# Closing positions at moment 370148
#
# Opening positions at moment 372975
# Closing positions at moment 373023
#
# Opening positions at moment 373071
# Closing positions at moment 373127
#
# Opening positions at moment 373139
# Closing positions at moment 373174
#
# Opening positions at moment 373219
# Closing positions at moment 373317
#
# Opening positions at moment 373319
# Closing positions at moment 373384
#
# Opening positions at moment 373447
# Closing positions at moment 373488
#
# Opening positions at moment 373527
# Closing positions at moment 373677
#
# Opening positions at moment 375639
# Closing positions at moment 375653
#
# Opening positions at moment 375659
# Closing positions at moment 376739
#
# Opening positions at moment 377776
# Closing positions at moment 377837
#
# Opening positions at moment 378257
# Closing positions at moment 378261
#
# Opening positions at moment 378325
# Closing positions at moment 379151
#
# Opening positions at moment 379152
# Closing positions at moment 379305
#
# Opening positions at moment 379338
# Closing positions at moment 379391
#
# Opening positions at moment 379439
# Closing positions at moment 379515
#
# Opening positions at moment 379871
# Closing positions at moment 379872
#
# Opening positions at moment 379949
# Closing positions at moment 380994
#
# Opening positions at moment 381015
# Closing positions at moment 384361
#
# Opening positions at moment 387906
# Closing positions at moment 387910
#
# Opening positions at moment 387922
# Closing positions at moment 387966
#
# Opening positions at moment 388156
# Closing positions at moment 388170
#
# Opening positions at moment 400555
# Closing positions at moment 400556
#
# Opening positions at moment 401420
# Closing positions at moment 401523
#
# Opening positions at moment 401548
# Closing positions at moment 401626
#
# Opening positions at moment 401996
# Closing positions at moment 402790
#
# Opening positions at moment 403888
# Closing positions at moment 404033
#
# Opening positions at moment 404056
# Closing positions at moment 406277
#
# Opening positions at moment 428524
# Closing positions at moment 428583
#
# Opening positions at moment 429751
# Closing positions at moment 429757
#
# Opening positions at moment 429759
# Closing positions at moment 429763
#
# Opening positions at moment 429764
# Closing positions at moment 429769
#
# Opening positions at moment 429770
# Closing positions at moment 429792
#
# Opening positions at moment 429793
# Closing positions at moment 429795
#
# Opening positions at moment 429796
# Closing positions at moment 429819
#
# Opening positions at moment 429859
# Closing positions at moment 429869
#
# Opening positions at moment 429870
# Closing positions at moment 429882
#
# Opening positions at moment 429883
# Closing positions at moment 429886
#
# Opening positions at moment 429887
# Closing positions at moment 429890
#
# Opening positions at moment 429891
# Closing positions at moment 429904
#
# Opening positions at moment 429905
# Closing positions at moment 429943
#
# Opening positions at moment 429944
# Closing positions at moment 429952
#
# Opening positions at moment 429953
# Closing positions at moment 430116
#
# Opening positions at moment 430174
# Closing positions at moment 430239
#
# Opening positions at moment 430283
# Closing positions at moment 430291
#
# Opening positions at moment 430748
# Closing positions at moment 430756
#
# Opening positions at moment 430875
# Closing positions at moment 430880
#
# Opening positions at moment 430882
# Closing positions at moment 430892
#
# Opening positions at moment 430893
# Closing positions at moment 430899
#
# Opening positions at moment 430900
# Closing positions at moment 430914
#
# Opening positions at moment 430915
# Closing positions at moment 430918
#
# Opening positions at moment 430919
# Closing positions at moment 430925
#
# Opening positions at moment 430928
# Closing positions at moment 430929
#
# Opening positions at moment 430930
# Closing positions at moment 430958
#
# Opening positions at moment 430959
# Closing positions at moment 430991
#
# Opening positions at moment 430992
# Closing positions at moment 430994
#
# Opening positions at moment 430995
# Closing positions at moment 431020
#
# Opening positions at moment 431021
# Closing positions at moment 431022
#
# Opening positions at moment 431023
# Closing positions at moment 431024
#
# Opening positions at moment 431025
# Closing positions at moment 431047
#
# Opening positions at moment 431048
# Closing positions at moment 431062
#
# Opening positions at moment 431063
# Closing positions at moment 431072
#
# Opening positions at moment 431073
# Closing positions at moment 431081
#
# Opening positions at moment 431082
# Closing positions at moment 431099
#
# Opening positions at moment 431100
# Closing positions at moment 431109
#
# Opening positions at moment 431110
# Closing positions at moment 431111
#
# Opening positions at moment 431112
# Closing positions at moment 431124
#
# Opening positions at moment 431125
# Closing positions at moment 431126
#
# Opening positions at moment 431127
# Closing positions at moment 431131
#
# Opening positions at moment 431132
# Closing positions at moment 431154
#
# Opening positions at moment 431155
# Closing positions at moment 431159
#
# Opening positions at moment 431160
# Closing positions at moment 431165
#
# Opening positions at moment 431166
# Closing positions at moment 431168
#
# Opening positions at moment 431169
# Closing positions at moment 431170
#
# Opening positions at moment 431171
# Closing positions at moment 431172
#
# Opening positions at moment 431173
# Closing positions at moment 431180
#
# Opening positions at moment 431181
# Closing positions at moment 431183
#
# Opening positions at moment 431184
# Closing positions at moment 431199
#
# Opening positions at moment 431200
# Closing positions at moment 431234
#
# Opening positions at moment 431239
# Closing positions at moment 431240
#
# Opening positions at moment 431242
# Closing positions at moment 431277
#
# Opening positions at moment 431280
# Closing positions at moment 431281
#
# Opening positions at moment 431287
# Closing positions at moment 431291
#
# Opening positions at moment 431294
# Closing positions at moment 431581
#
# Opening positions at moment 431630
# Closing positions at moment 431639
#
# Opening positions at moment 431645
# Closing positions at moment 431647
#
# Opening positions at moment 431667
# Closing positions at moment 431674
#
# Opening positions at moment 431697
# Closing positions at moment 431704
#
# Opening positions at moment 431718
# Closing positions at moment 431719
#
# Opening positions at moment 431720
# Closing positions at moment 431730
#
# Opening positions at moment 431763
# Closing positions at moment 431779
#
# Opening positions at moment 431780
# Closing positions at moment 431781
#
# Opening positions at moment 431782
# Closing positions at moment 431801
#
# Opening positions at moment 431802
# Closing positions at moment 431808
#
# Opening positions at moment 431809
# Closing positions at moment 431813
#
# Opening positions at moment 431814
# Closing positions at moment 431828
#
# Opening positions at moment 431829
# Closing positions at moment 431832
#
# Opening positions at moment 431833
# Closing positions at moment 431840
#
# Opening positions at moment 431841
# Closing positions at moment 431844
#
# Opening positions at moment 431845
# Closing positions at moment 431846
#
# Opening positions at moment 431847
# Closing positions at moment 431854
#
# Opening positions at moment 431855
# Closing positions at moment 431861
#
# Opening positions at moment 431862
# Closing positions at moment 431866
#
# Opening positions at moment 431867
# Closing positions at moment 431881
#
# Opening positions at moment 431882
# Closing positions at moment 431887
#
# Opening positions at moment 431888
# Closing positions at moment 431901
#
# Opening positions at moment 431902
# Closing positions at moment 431903
#
# Opening positions at moment 431904
# Closing positions at moment 431907
#
# Opening positions at moment 431908
# Closing positions at moment 431909
#
# Opening positions at moment 431910
# Closing positions at moment 431921
#
# Opening positions at moment 431922
# Closing positions at moment 431923
#
# Opening positions at moment 431924
# Closing positions at moment 431938
#
# Opening positions at moment 431939
# Closing positions at moment 431947
#
# Opening positions at moment 431948
# Closing positions at moment 431955
#
# Opening positions at moment 431956
# Closing positions at moment 431962
#
# Opening positions at moment 431963
# Closing positions at moment 431980
#
# Opening positions at moment 431981
# Closing positions at moment 431990
#
# Opening positions at moment 431991
# Closing positions at moment 431993
#
# Opening positions at moment 431994
# Closing positions at moment 432011
#
# Opening positions at moment 432012
# Closing positions at moment 432018
#
# Opening positions at moment 432019
# Closing positions at moment 432044
#
# Opening positions at moment 432045
# Closing positions at moment 432048
#
# Opening positions at moment 432049
# Closing positions at moment 432050
#
# Opening positions at moment 432051
# Closing positions at moment 432053
#
# Opening positions at moment 432054
# Closing positions at moment 435975
#
# Opening positions at moment 435987
# Closing positions at moment 436514
#
# Opening positions at moment 439211
# Closing positions at moment 439212
#
# Opening positions at moment 439214
# Closing positions at moment 439237
#
# Opening positions at moment 439269
# Closing positions at moment 439319
#
# Opening positions at moment 439335
# Closing positions at moment 439339
#
# Opening positions at moment 445153
# Closing positions at moment 445155
#
# Opening positions at moment 446186
# Closing positions at moment 446202
#
# Opening positions at moment 446274
# Closing positions at moment 446282
#
# Opening positions at moment 446283
# Closing positions at moment 446319
#
# Opening positions at moment 446526
# Closing positions at moment 456527
#
# Opening positions at moment 456528
# Closing positions at moment 456689
#
# Opening positions at moment 456690
# Closing positions at moment 458482
#
# Opening positions at moment 458483
# Closing positions at moment 458518
#
# Opening positions at moment 458522
# Closing positions at moment 458585
#
# Opening positions at moment 458586
# Closing positions at moment 458701
#
# Opening positions at moment 458702
# Closing positions at moment 458728
#
# Opening positions at moment 458729
# Closing positions at moment 458857
#
# Opening positions at moment 458973
# Closing positions at moment 458986
#
# Opening positions at moment 458996
# Closing positions at moment 458998
#
# Opening positions at moment 459034
# Closing positions at moment 459111
#
# Opening positions at moment 459223
# Closing positions at moment 459255
#
# Opening positions at moment 459262
# Closing positions at moment 459281
#
# Opening positions at moment 459290
# Closing positions at moment 459302
#
# Opening positions at moment 459329
# Closing positions at moment 459614
#
# Opening positions at moment 459615
# Closing positions at moment 459627
#
# Opening positions at moment 459629
# Closing positions at moment 459632
#
# Opening positions at moment 459633
# Closing positions at moment 459698
#
# Opening positions at moment 459756
# Closing positions at moment 459757
#
# Opening positions at moment 459761
# Closing positions at moment 459766
#
# Opening positions at moment 459769
# Closing positions at moment 459846
#
# Opening positions at moment 459847
# Closing positions at moment 459975
#
# Opening positions at moment 459977
# Closing positions at moment 459985
#
# Opening positions at moment 459986
# Closing positions at moment 460114
#
# Opening positions at moment 460115
# Closing positions at moment 460153
#
# Opening positions at moment 460154
# Closing positions at moment 460190
#
# Opening positions at moment 460191
# Closing positions at moment 460196
#
# Opening positions at moment 460205
# Closing positions at moment 460271
#
# Opening positions at moment 460274
# Closing positions at moment 460282
#
# Opening positions at moment 460312
# Closing positions at moment 460315
#
# Opening positions at moment 460322
# Closing positions at moment 460356
#
# Opening positions at moment 460357
# Closing positions at moment 460623
#
# Opening positions at moment 460624
# Closing positions at moment 460632
#
# Opening positions at moment 460633
# Closing positions at moment 460923
#
# Opening positions at moment 460924
# Closing positions at moment 460928
#
# Opening positions at moment 460929
# Closing positions at moment 460930
#
# Opening positions at moment 460931
# Closing positions at moment 470932
#
# Opening positions at moment 470933
# Closing positions at moment 473706
#
# Opening positions at moment 473707
# Closing positions at moment 473775
#
# Opening positions at moment 473776
# Closing positions at moment 473801
#
# Opening positions at moment 473802
# Closing positions at moment 473835
#
# Opening positions at moment 473836
# Closing positions at moment 473840
#
# Opening positions at moment 473841
# Closing positions at moment 473859
#
# Opening positions at moment 473860
# Closing positions at moment 473862
#
# Opening positions at moment 473863
# Closing positions at moment 473953
#
# Opening positions at moment 473954
# Closing positions at moment 473955
#
# Opening positions at moment 473956
# Closing positions at moment 473994
#
# Opening positions at moment 473995
# Closing positions at moment 474013
#
# Opening positions at moment 474014
# Closing positions at moment 474024
#
# Opening positions at moment 474025
# Closing positions at moment 474038
#
# Opening positions at moment 474039
# Closing positions at moment 474147
#
# Opening positions at moment 474148
# Closing positions at moment 474152
#
# Opening positions at moment 474153
# Closing positions at moment 474176
#
# Opening positions at moment 474177
# Closing positions at moment 474208
#
# Opening positions at moment 474209
# Closing positions at moment 478911
#
# Opening positions at moment 478912
# Closing positions at moment 479256
#
# Opening positions at moment 479257
# Closing positions at moment 479658
#
# Opening positions at moment 479659
# Closing positions at moment 479751
#
# Opening positions at moment 479752
# Closing positions at moment 480570
#
# Opening positions at moment 480571
# Closing positions at moment 480667
#
# Opening positions at moment 480668
# Closing positions at moment 481701
#
# Opening positions at moment 481702
# Closing positions at moment 481773
#
# Opening positions at moment 481774
# Closing positions at moment 481780
#
# Opening positions at moment 481781
# Closing positions at moment 481803
#
# Opening positions at moment 481804
# Closing positions at moment 481807
#
# Opening positions at moment 481808
# Closing positions at moment 481841
#
# Opening positions at moment 481842
# Closing positions at moment 481873
#
# Opening positions at moment 481874
# Closing positions at moment 481904
#
# Opening positions at moment 481905
# Closing positions at moment 481919
#
# Opening positions at moment 481920
# Closing positions at moment 481959
#
# Opening positions at moment 481960
# Closing positions at moment 481971
#
# Opening positions at moment 481972
# Closing positions at moment 481999
#
# Opening positions at moment 482000
# Closing positions at moment 482004
#
# Opening positions at moment 482005
# Closing positions at moment 482007
#
# Opening positions at moment 482008
# Closing positions at moment 482044
#
# Opening positions at moment 482045
# Closing positions at moment 482055
#
# Opening positions at moment 482056
# Closing positions at moment 482091
#
# Opening positions at moment 482092
# Closing positions at moment 482213
#
# Opening positions at moment 482214
# Closing positions at moment 482219
#
# Opening positions at moment 482220
# Closing positions at moment 482456
#
# Opening positions at moment 482457
# Closing positions at moment 483739
#
# Opening positions at moment 483740
# Closing positions at moment 483849
#
# Opening positions at moment 483850
# Closing positions at moment 484142
#
# Opening positions at moment 484143
# Closing positions at moment 485488
#
# Opening positions at moment 485489
# Closing positions at moment 486691
#
# Opening positions at moment 486802
# Closing positions at moment 487162
#
# Opening positions at moment 487163
# Closing positions at moment 487179
#
# Opening positions at moment 487217
# Closing positions at moment 487285
#
# Opening positions at moment 487584
# Closing positions at moment 487595
#
# Opening positions at moment 487625
# Closing positions at moment 487767
#
# Opening positions at moment 487768
# Closing positions at moment 487828
#
# Opening positions at moment 487829
# Closing positions at moment 488013
#
# Opening positions at moment 488020
# Closing positions at moment 488307
#
# Opening positions at moment 488308
# Closing positions at moment 498309
#
# Opening positions at moment 498310
# Closing positions at moment 503656
#
# Opening positions at moment 503657
# Closing positions at moment 503953
#
# Opening positions at moment 503954
# Closing positions at moment 503961
#
# Opening positions at moment 503962
# Closing positions at moment 504135
#
# Opening positions at moment 504136
# Closing positions at moment 505757
#
# Opening positions at moment 505758
# Closing positions at moment 505810
#
# Opening positions at moment 505811
# Closing positions at moment 509546
#
# Opening positions at moment 509547
# Closing positions at moment 509808
#
# Opening positions at moment 509817
# Closing positions at moment 519818
#
# Opening positions at moment 519819
# Closing positions at moment 529820
#
# Opening positions at moment 529821
# Closing positions at moment 533525
#
# Opening positions at moment 533526
# Closing positions at moment 533872
# Capital after performing the algorithm: 23587.4734261
